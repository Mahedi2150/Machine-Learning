# %%
import numpy as np

# %%
arr_1d = np.array([1,2,3,4])
arr_2d = np.array([[1,2,3],[5,6,7]])

# %%
print(arr_1d)
# Out:
# [1 2 3 4]

# %%
type(arr_1d)
# Out:
# numpy.ndarray

# %%
arr_1d.ndim
# Out:
# 1

# %%
print(arr_2d)
# Out:
# [[1 2 3]
#  [5 6 7]]

# %%
type(arr_2d)
# Out:
# numpy.ndarray

# %%
arr_2d.ndim
# Out:
# 2

# %%
arr_2d.size
# Out:
# 6

# %%
arr_2d.shape
# Out:
# (2, 3)

# %%
arr_2d.dtype
# Out:
# dtype('int64')
